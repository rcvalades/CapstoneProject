# %% [markdown]
# # CapStone Project
# Name: Richard Valades
# Updated: 2022.12.13

# %% [markdown]
# # The goal of this project is to create and evaluate 4 Machine Learning Models to make predictions on location based on wi-fi signal data

# %%
# Based on the wi-fi signals project that was created in R.
# This project follows a similar process with the learnings from that project being applied in a Python environment.

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset
LocData = pd.read_csv('TrainingData.csv', index_col=False)
print(LocData.shape)
# Out:
# (19937, 529)

# %%
#Examine the features of the data
LocData.head()
# Out:
#    LONGITUDE     LATITUDE  FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  \
# 0 -7541.2643  4864920.778      2           1      106                 2
# 1 -7536.6212  4864934.225      2           1      106                 2
# 2 -7519.1524  4864949.532      2           1      103                 2
# 3 -7524.5704  4864934.093      2           1      102                 2
# 4 -7632.1436  4864982.217      0           0      122                 2
#
#    USERID  PHONEID   TIMESTAMP  WAP001  ...  WAP511  WAP512  WAP513  WAP514  \
# 0       2       23  1371713733     100  ...     100     100     100     100
# 1       2       23  1371713691     100  ...     100     100     100     100
# 2       2       23  1371714095     100  ...     100     100     100     100
# 3       2       23  1371713807     100  ...     100     100     100     100
# 4      11       13  1369909710     100  ...     100     100     100     100
#
#    WAP515  WAP516  WAP517  WAP518  WAP519  WAP520
# 0     100     100     100     100     100     100
# 1     100     100     100     100     100     100
# 2     100     100     100     100     100     100
# 3     100     100     100     100     100     100
# 4     100     100     100     100     100     100
#
# [5 rows x 529 columns]

# %%
#Remove unnecessary features
LocData = LocData.drop(columns=['USERID','PHONEID','LONGITUDE','LATITUDE','TIMESTAMP'])

# %%
LocData.head()
# Out:
#    FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  WAP001  WAP002  WAP003  \
# 0      2           1      106                 2     100     100     100
# 1      2           1      106                 2     100     100     100
# 2      2           1      103                 2     100     100     100
# 3      2           1      102                 2     100     100     100
# 4      0           0      122                 2     100     100     100
#
#    WAP004  WAP005  WAP006  ...  WAP511  WAP512  WAP513  WAP514  WAP515  \
# 0     100     100     100  ...     100     100     100     100     100
# 1     100     100     100  ...     100     100     100     100     100
# 2     100     100     100  ...     100     100     100     100     100
# 3     100     100     100  ...     100     100     100     100     100
# 4     100     100     100  ...     100     100     100     100     100
#
#    WAP516  WAP517  WAP518  WAP519  WAP520
# 0     100     100     100     100     100
# 1     100     100     100     100     100
# 2     100     100     100     100     100
# 3     100     100     100     100     100
# 4     100     100     100     100     100
#
# [5 rows x 524 columns]

# %%
#Check data types
LocData.dtypes
# Out:
# FLOOR               int64
# BUILDINGID          int64
# SPACEID             int64
# RELATIVEPOSITION    int64
# WAP001              int64
#                     ...
# WAP516              int64
# WAP517              int64
# WAP518              int64
# WAP519              int64
# WAP520              int64
# Length: 524, dtype: object

# %%
#Change data type to string to combine columns for dependent variable
LocData = LocData.astype(str)

# %%
#Confirm data types
LocData.dtypes
# Out:
# FLOOR               object
# BUILDINGID          object
# SPACEID             object
# RELATIVEPOSITION    object
# WAP001              object
#                      ...
# WAP516              object
# WAP517              object
# WAP518              object
# WAP519              object
# WAP520              object
# Length: 524, dtype: object

# %%
#combine columns to create unique location ID as depedent variable
LocData['POSITIONID'] = LocData['FLOOR'] + LocData['BUILDINGID'] + LocData['SPACEID'] + LocData['RELATIVEPOSITION']

# %%
#Confirm new object is created
LocData.head()
# Out:
#   FLOOR BUILDINGID SPACEID RELATIVEPOSITION WAP001 WAP002 WAP003 WAP004  \
# 0     2          1     106                2    100    100    100    100
# 1     2          1     106                2    100    100    100    100
# 2     2          1     103                2    100    100    100    100
# 3     2          1     102                2    100    100    100    100
# 4     0          0     122                2    100    100    100    100
#
#   WAP005 WAP006  ... WAP512 WAP513 WAP514 WAP515 WAP516 WAP517 WAP518 WAP519  \
# 0    100    100  ...    100    100    100    100    100    100    100    100
# 1    100    100  ...    100    100    100    100    100    100    100    100
# 2    100    100  ...    100    100    100    100    100    100    100    100
# 3    100    100  ...    100    100    100    100    100    100    100    100
# 4    100    100  ...    100    100    100    100    100    100    100    100
#
#   WAP520 POSITIONID
# 0    100     211062
# 1    100     211062
# 2    100     211032
# 3    100     211022
# 4    100     001222
#
# [5 rows x 525 columns]

# %%
#Change data types back to integer for modeling
LocData = LocData.astype(np.int64)

# %%
#Confirm data types
LocData.dtypes
# Out:
# FLOOR               int64
# BUILDINGID          int64
# SPACEID             int64
# RELATIVEPOSITION    int64
# WAP001              int64
#                     ...
# WAP517              int64
# WAP518              int64
# WAP519              int64
# WAP520              int64
# POSITIONID          int64
# Length: 525, dtype: object

# %%
#Confirm features
LocData.head()
# Out:
#    FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  WAP001  WAP002  WAP003  \
# 0      2           1      106                 2     100     100     100
# 1      2           1      106                 2     100     100     100
# 2      2           1      103                 2     100     100     100
# 3      2           1      102                 2     100     100     100
# 4      0           0      122                 2     100     100     100
#
#    WAP004  WAP005  WAP006  ...  WAP512  WAP513  WAP514  WAP515  WAP516  \
# 0     100     100     100  ...     100     100     100     100     100
# 1     100     100     100  ...     100     100     100     100     100
# 2     100     100     100  ...     100     100     100     100     100
# 3     100     100     100  ...     100     100     100     100     100
# 4     100     100     100  ...     100     100     100     100     100
#
#    WAP517  WAP518  WAP519  WAP520  POSITIONID
# 0     100     100     100     100      211062
# 1     100     100     100     100      211062
# 2     100     100     100     100      211032
# 3     100     100     100     100      211022
# 4     100     100     100     100        1222
#
# [5 rows x 525 columns]

# %%
# Verify shape of data after feature engineering
LocData.shape
# Out:
# (19937, 525)

# %%
print(LocData)
# Out:
#        FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  WAP001  WAP002  WAP003  \
# 0          2           1      106                 2     100     100     100
# 1          2           1      106                 2     100     100     100
# 2          2           1      103                 2     100     100     100
# 3          2           1      102                 2     100     100     100
# 4          0           0      122                 2     100     100     100
# ...      ...         ...      ...               ...     ...     ...     ...
# 19932      3           1        1                 2     100     100     100
# 19933      1           2      140                 2     100     100     100
# 19934      3           1       13                 2     100     100     100
# 19935      3           1      113                 2     100     100     100
# 19936      3           1      112                 2     100     100     100
#
#        WAP004  WAP005  WAP006  ...  WAP512  WAP513  WAP514  WAP515  WAP516  \
# 0         100     100     100  ...     100     100     100     100     100
# 1         100     100     100  ...     100     100     100     100     100
# 2         100     100     100  ...     100     100     100     100     100
# 3         100     100     100  ...     100     100     100     100     100
# 4         100     100     100  ...     100     100     100     100     100
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 19932     100     100     100  ...     100     100     100     100     100
# 19933     100     100     100  ...     100     100     100     100     100
# 19934     100     100     100  ...     100     100     100     100     100
# 19935     100     100     100  ...     100     100     100     100     100
# 19936     100     100     100  ...     100     100     100     100     100
#
#        WAP517  WAP518  WAP519  WAP520  POSITIONID
# 0         100     100     100     100      211062
# 1         100     100     100     100      211062
# 2         100     100     100     100      211032
# 3         100     100     100     100      211022
# 4         100     100     100     100        1222
# ...       ...     ...     ...     ...         ...
# 19932     100     100     100     100        3112
# 19933     100     100     100     100      121402
# 19934     100     100     100     100       31132
# 19935     100     100     100     100      311132
# 19936     100     100     100     100      311122
#
# [19937 rows x 525 columns]

# %%
# Subset data to one building
LocData = LocData[LocData['BUILDINGID'] == 1]

# %%
# Confirm only building 1 is present in dataset
print(LocData)
# Out:
#        FLOOR  BUILDINGID  SPACEID  RELATIVEPOSITION  WAP001  WAP002  WAP003  \
# 0          2           1      106                 2     100     100     100
# 1          2           1      106                 2     100     100     100
# 2          2           1      103                 2     100     100     100
# 3          2           1      102                 2     100     100     100
# 5          2           1      105                 2     100     100     100
# ...      ...         ...      ...               ...     ...     ...     ...
# 19930      3           1        4                 2     100     100     100
# 19932      3           1        1                 2     100     100     100
# 19934      3           1       13                 2     100     100     100
# 19935      3           1      113                 2     100     100     100
# 19936      3           1      112                 2     100     100     100
#
#        WAP004  WAP005  WAP006  ...  WAP512  WAP513  WAP514  WAP515  WAP516  \
# 0         100     100     100  ...     100     100     100     100     100
# 1         100     100     100  ...     100     100     100     100     100
# 2         100     100     100  ...     100     100     100     100     100
# 3         100     100     100  ...     100     100     100     100     100
# 5         100     100     100  ...     100     100     100     100     100
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 19930     100     100     100  ...     100     100     100     100     100
# 19932     100     100     100  ...     100     100     100     100     100
# 19934     100     100     100  ...     100     100     100     100     100
# 19935     100     100     100  ...     100     100     100     100     100
# 19936     100     100     100  ...     100     100     100     100     100
#
#        WAP517  WAP518  WAP519  WAP520  POSITIONID
# 0         100     100     100     100      211062
# 1         100     100     100     100      211062
# 2         100     100     100     100      211032
# 3         100     100     100     100      211022
# 5         100     100     100     100      211052
# ...       ...     ...     ...     ...         ...
# 19930     100     100     100     100        3142
# 19932     100     100     100     100        3112
# 19934     100     100     100     100       31132
# 19935     100     100     100     100      311132
# 19936     100     100     100     100      311122
#
# [5196 rows x 525 columns]

# %%
LocData.shape
# Out:
# (5196, 525)

# %%
# Remove unnecessary features
LocData = LocData.drop(columns=['FLOOR','BUILDINGID','SPACEID','RELATIVEPOSITION'])

# %%
# Confirm dataset after feature elimination
LocData.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 5     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  WAP518  \
# 0     100  ...     100     100     100     100     100     100     100
# 1     100  ...     100     100     100     100     100     100     100
# 2     100  ...     100     100     100     100     100     100     100
# 3     100  ...     100     100     100     100     100     100     100
# 5     100  ...     100     100     100     100     100     100     100
#
#    WAP519  WAP520  POSITIONID
# 0     100     100      211062
# 1     100     100      211062
# 2     100     100      211032
# 3     100     100      211022
# 5     100     100      211052
#
# [5 rows x 521 columns]

# %% [markdown]
# # Set seed and create objects for Train/Test Sets

# %%
#Set random sead
seed = 123

# %%
# Select Features and Dependent variable
Y_Location = LocData['POSITIONID']
X_Location = LocData.iloc[:,0:520]

# %%
# Check that IV columns are correct
X_Location.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 5     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP511  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  \
# 0     100  ...     100     100     100     100     100     100     100
# 1     100  ...     100     100     100     100     100     100     100
# 2     100  ...     100     100     100     100     100     100     100
# 3     100  ...     100     100     100     100     100     100     100
# 5     100  ...     100     100     100     100     100     100     100
#
#    WAP518  WAP519  WAP520
# 0     100     100     100
# 1     100     100     100
# 2     100     100     100
# 3     100     100     100
# 5     100     100     100
#
# [5 rows x 520 columns]

# %% [markdown]
# # Create Train and Test Sets

# %%
#Split data into training and test sets with 70/30 split

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_Location,
                                            Y_Location,
                                            test_size = .30,
                                            random_state = seed)

print(X_Train.shape, X_Test.shape)
print(Y_Train.shape, Y_Test.shape)
# Out:
# (3637, 520) (1559, 520)
# (3637,) (1559,)

# %% [markdown]
# # Create Models

# %%
# select classification algorithms 

algos = []
algos.append(('Random Forest Classifier', RandomForestClassifier()))
algos.append(('Gradient Boosting Classifier', GradientBoostingClassifier()))
algos.append(('Decision Tree Classifier', DecisionTreeClassifier()))
algos.append(('KNeighbors Classifier', KNeighborsClassifier()))

# %%
# build models

results = []
names = []

for name, model in algos:
    result = cross_val_score(model, X_Train, Y_Train, cv=4)
    names.append(name)
    results.append(result)

# %%
# evaluate results

for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# Random Forest Classifier 0.8325541894848825
# Gradient Boosting Classifier 0.5691527944003192
# Decision Tree Classifier 0.6406399980657407
# KNeighbors Classifier 0.5993934283538244

# %% [markdown]
# # Validate

# %%
#Select best model(s) to tune and validate with the test set

bestAlgo = RandomForestClassifier()
bestAlgopred = bestAlgo.fit(X_Train, Y_Train).predict(X_Test)
print(classification_report(Y_Test, bestAlgopred))
print(confusion_matrix(Y_Test, bestAlgopred))
# Out:
#               precision    recall  f1-score   support
#
#          111       1.00      1.00      1.00         3
#          112       0.83      1.00      0.91         5
#          132       1.00      0.86      0.92         7
#       211011       1.00      1.00      1.00         3
#       211012       1.00      1.00      1.00        13
#       211021       1.00      1.00      1.00         2
#       211022       1.00      1.00      1.00         6
#       211031       1.00      1.00      1.00         2
#       211032       1.00      1.00      1.00        11
#       211041       1.00      1.00      1.00         8
#       211042       1.00      1.00      1.00         5
#       211051       1.00      1.00      1.00         4
#       211052       1.00      1.00      1.00         5
#       211061       1.00      1.00      1.00         2
#       211062       1.00      1.00      1.00         9
#       211072       1.00      0.88      0.93         8
#       211082       1.00      0.60      0.75        10
#       211092       0.71      1.00      0.83         5
#       211102       1.00      1.00      1.00         5
#       211112       0.80      1.00      0.89         8
#       211121       0.00      0.00      0.00         1
#       211122       0.60      1.00      0.75         3
#       211172       1.00      1.00      1.00         2
#       212011       1.00      1.00      1.00        10
#       212012       1.00      1.00      1.00        18
#       212021       0.94      1.00      0.97        17
#       212022       1.00      1.00      1.00         8
#       212031       1.00      0.80      0.89         5
#       212032       0.88      1.00      0.93         7
#       212041       1.00      1.00      1.00         3
#       212042       1.00      1.00      1.00         9
#       212052       1.00      1.00      1.00         4
#       212061       1.00      1.00      1.00         9
#       212062       1.00      0.92      0.96        12
#       212072       1.00      1.00      1.00         4
#       212082       1.00      1.00      1.00         6
#       212092       1.00      1.00      1.00         4
#       212102       1.00      1.00      1.00         6
#       212112       0.83      1.00      0.91         5
#       212121       1.00      1.00      1.00         7
#       212122       1.00      0.89      0.94         9
#       212162       1.00      0.94      0.97        16
#       212171       1.00      1.00      1.00         2
#       212172       0.88      1.00      0.93         7
#       311011       0.88      0.88      0.88         8
#       311012       0.63      0.86      0.73        14
#       311021       1.00      0.83      0.91         6
#       311022       0.50      0.90      0.64        10
#       311031       0.83      0.83      0.83         6
#       311032       0.62      1.00      0.77         5
#       311041       1.00      0.83      0.91         6
#       311042       1.00      0.60      0.75        15
#       311052       0.60      1.00      0.75         3
#       311062       1.00      0.88      0.93         8
#       311072       0.67      1.00      0.80         2
#       311082       1.00      0.71      0.83         7
#       311122       0.83      1.00      0.91         5
#       311131       1.00      1.00      1.00         2
#       311132       1.00      0.73      0.84        11
#       311161       1.00      0.70      0.82        10
#       311162       1.00      0.75      0.86         4
#       312011       1.00      0.40      0.57         5
#       312012       0.77      1.00      0.87        10
#       312021       1.00      1.00      1.00         2
#       312022       0.95      0.91      0.93        22
#       312032       0.91      0.87      0.89        23
#       312042       0.75      0.90      0.82        10
#       312052       1.00      0.33      0.50         3
#       312062       0.50      1.00      0.67         2
#       312142       1.00      1.00      1.00         3
#       312162       0.90      1.00      0.95         9
#       312172       1.00      0.88      0.93         8
#
#     accuracy                           0.87      1559
#    macro avg       0.86      0.84      0.83      1559
# weighted avg       0.89      0.87      0.86      1559
#
# [[3 0 0 ... 0 0 0]
#  [0 5 0 ... 0 0 0]
#  [0 1 6 ... 0 0 0]
#  ...
#  [0 0 0 ... 3 0 0]
#  [0 0 0 ... 0 9 0]
#  [0 0 0 ... 0 0 7]]

# %% [markdown]
# # Predict

# %%
predictions = bestAlgo.predict(X_Test)

# %%
print(predictions)
# Out:
# [  2192  12032 212032 ... 111071  11192   1101]
